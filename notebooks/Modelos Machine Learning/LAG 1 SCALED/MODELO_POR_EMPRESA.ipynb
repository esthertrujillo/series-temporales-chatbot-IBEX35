# %%
import sys
sys.path.append('/Users/luciamenendezfernandez/Desktop/TFM lucia/src/lag1_funciones')

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
ruta_datos = "/Users/luciamenendezfernandez/Desktop/TFM lucia/data/IBEX35_cotizaciones_20_Limpio.csv"

import pandas as pd
df_all = pd.read_csv(ruta_datos)
print(df_all["Empresa"].unique())
# Out:
# [nan 'ACCIONA' 'ACCIONA ENERGÍA' 'ACERINOX' 'ACS' 'AENA' 'AMADEUS'
#  'ARCELORMITTAL' 'BANKINTER' 'BBVA' 'CAIXABANK' 'CELLNEX TELECOM' 'ENAGAS'
#  'ENDESA' 'FERROVIAL' 'FLUIDRA' 'GRIFOLS' 'IAG' 'IBERDROLA' 'INDITEX'
#  'INDRA' 'INM. COLONIAL' 'LABORATORIOS FARMA (ROVI)' 'LOGISTA' 'MAPFRE'
#  'MERLIN PROPERTIES' 'NATURGY' 'PUIG' 'REE' 'REPSOL' 'SABADELL' 'SACYR'
#  'SANTANDER' 'SOLARIA ENERGIA' 'TELEFONICA' 'UNICAJA BANCO']

# %%
import sys
import pandas as pd
sys.path.append('/Users/luciamenendezfernandez/Desktop/TFM lucia/src/lag1_funciones')

# %%
import sys
import os

from scaling import escalar_datos
from preprocessing import cargar_datos
from features import crear_variables_lag_y_temporales
from model_training import dividir_train_test, definir_modelos, entrenar_y_evaluar_modelos
from visualization import graficar_predicciones

# %% [markdown]
# ACCIONA

# %%
# --- CONFIGURACIÓN INICIAL ---
import sys
import os

from scaling import escalar_datos
from preprocessing import cargar_datos
from features import crear_variables_lag_y_temporales
from model_training import dividir_train_test, definir_modelos, entrenar_y_evaluar_modelos
from visualization import graficar_predicciones

# --- PARÁMETROS ---
empresa = "ACCIONA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 2.4309631921218435
# Entrenando Decision Tree...
# Decision Tree - RMSE: 12.227597363887973
# Entrenando Random Forest...
# Random Forest - RMSE: 11.463923028544778
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 12.618589900719613
# Entrenando XGBoost...
# XGBoost - RMSE: 13.016945680696361
# Entrenando SVR...
# SVR - RMSE: 2.4011160352954133
# 🏆 Mejor modelo: SVR con RMSE: 2.4011

# %% [markdown]
# ACCIONA ENERGÍA

# %%
# --- PARÁMETROS ---
empresa = "ACCIONA ENERGÍA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 21.25134921884796
# Entrenando Decision Tree...
# Decision Tree - RMSE: 6.473585222557497
# Entrenando Random Forest...
# Random Forest - RMSE: 5.894128289229726
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 6.400500048299519
# Entrenando XGBoost...
# XGBoost - RMSE: 6.476980522919665
# Entrenando SVR...
# SVR - RMSE: 3.436796957143842
# 🏆 Mejor modelo: SVR con RMSE: 3.4368

# %% [markdown]
# ACERINOX

# %%
# --- PARÁMETROS ---
empresa = "ACERINOX"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.14392112084389078
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.4629585641834749
# Entrenando Random Forest...
# Random Forest - RMSE: 0.3270903278706207
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.3661430451149939
# Entrenando XGBoost...
# XGBoost - RMSE: 0.3773725507338675
# Entrenando SVR...
# SVR - RMSE: 0.14365729054916768
# 🏆 Mejor modelo: SVR con RMSE: 0.1437

# %% [markdown]
# ACS

# %%
# --- PARÁMETROS ---

empresa = "ACS"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.453458258476781
# Entrenando Decision Tree...
# Decision Tree - RMSE: 11.078082489243588
# Entrenando Random Forest...
# Random Forest - RMSE: 10.96088060312795
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 10.98739036332033
# Entrenando XGBoost...
# XGBoost - RMSE: 10.953602432438478
# Entrenando SVR...
# SVR - RMSE: 0.4483669568459238
# 🏆 Mejor modelo: SVR con RMSE: 0.4484

# %% [markdown]
# AENA

# %%
# --- PARÁMETROS ---

empresa = "AENA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 21.333869235632
# Entrenando Decision Tree...
# Decision Tree - RMSE: 33.8473414093345
# Entrenando Random Forest...
# Random Forest - RMSE: 33.41511174490844
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 34.12640248715987
# Entrenando XGBoost...
# XGBoost - RMSE: 33.4745554065204
# Entrenando SVR...
# SVR - RMSE: 3.5811135928215094
# 🏆 Mejor modelo: SVR con RMSE: 3.5811

# %% [markdown]
# AMADEUS

# %%
# --- PARÁMETROS ---

empresa = "AMADEUS"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 1.3533120826683906
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.993040232277595
# Entrenando Random Forest...
# Random Forest - RMSE: 0.9022908752673895
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.4734419883675427
# Entrenando XGBoost...
# XGBoost - RMSE: 1.62567431882993
# Entrenando SVR...
# SVR - RMSE: 0.9809324995312043
# 🏆 Mejor modelo: Random Forest con RMSE: 0.9023

# %% [markdown]
# ARCELORMITTAL

# %%
# --- PARÁMETROS ---

empresa = "ARCELORMITTAL"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.5127065617282454
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.5672066220995514
# Entrenando Random Forest...
# Random Forest - RMSE: 0.5368761245612513
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.5751948229020054
# Entrenando XGBoost...
# XGBoost - RMSE: 0.5894307569573117
# Entrenando SVR...
# SVR - RMSE: 0.5230550324925701
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.5127

# %% [markdown]
# BANKINTER

# %%
# --- PARÁMETROS ---

empresa = "BANKINTER"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.10502914529412422
# Entrenando Decision Tree...
# Decision Tree - RMSE: 1.9823056387201823
# Entrenando Random Forest...
# Random Forest - RMSE: 1.9448764876147047
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.9144751356136107
# Entrenando XGBoost...
# XGBoost - RMSE: 1.9820183893259686
# Entrenando SVR...
# SVR - RMSE: 0.10413273784896335
# 🏆 Mejor modelo: SVR con RMSE: 0.1041

# %% [markdown]
# BBVA

# %%
# --- PARÁMETROS ---

empresa = "BBVA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.15018895821895586
# Entrenando Decision Tree...
# Decision Tree - RMSE: 2.7511942038536352
# Entrenando Random Forest...
# Random Forest - RMSE: 2.775018060957002
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 2.8030836124790888
# Entrenando XGBoost...
# XGBoost - RMSE: 2.845449726615343
# Entrenando SVR...
# SVR - RMSE: 0.1563858175872797
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.1502

# %% [markdown]
# CAIXABANK

# %%
# --- PARÁMETROS ---

empresa = "CAIXABANK"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.0731795367539413
# Entrenando Decision Tree...
# Decision Tree - RMSE: 1.4370719372024643
# Entrenando Random Forest...
# Random Forest - RMSE: 1.4403781502069477
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.4716236988791822
# Entrenando XGBoost...
# XGBoost - RMSE: 1.4626441514094823
# Entrenando SVR...
# SVR - RMSE: 0.07676949051158356
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.0732

# %% [markdown]
# CELLNEX

# %%
# --- PARÁMETROS ---

empresa = "CELLNEX TELECOM"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 31.569127603115675
# Entrenando Decision Tree...
# Decision Tree - RMSE: 5.175164639193327
# Entrenando Random Forest...
# Random Forest - RMSE: 5.1310763463776246
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 6.5091657084646615
# Entrenando XGBoost...
# XGBoost - RMSE: 5.9688060610695155
# Entrenando SVR...
# SVR - RMSE: 3.687566914082741
# 🏆 Mejor modelo: SVR con RMSE: 3.6876

# %% [markdown]
# ENAGAS

# %%
# --- PARÁMETROS ---

empresa = "ENAGAS"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.16858196880700788
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.27632687712769444
# Entrenando Random Forest...
# Random Forest - RMSE: 0.16677288890095945
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.2167594282143955
# Entrenando XGBoost...
# XGBoost - RMSE: 0.17173255004766616
# Entrenando SVR...
# SVR - RMSE: 0.16725005005289983
# 🏆 Mejor modelo: Random Forest con RMSE: 0.1668

# %% [markdown]
# ENDESA

# %%
# --- PARÁMETROS ---

empresa = "ENDESA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.21309727595404668
# Entrenando Decision Tree...
# Decision Tree - RMSE: 1.4058514984421522
# Entrenando Random Forest...
# Random Forest - RMSE: 1.3187262113936205
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.6611955350324836
# Entrenando XGBoost...
# XGBoost - RMSE: 1.4419100964565785
# Entrenando SVR...
# SVR - RMSE: 0.2289793975239192
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.2131

# %% [markdown]
# FERROVIAL

# %%
# --- PARÁMETROS ---

empresa = "FERROVIAL"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.3796530743509125
# Entrenando Decision Tree...
# Decision Tree - RMSE: 7.690547723145953
# Entrenando Random Forest...
# Random Forest - RMSE: 7.11334836354013
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 7.741777019555797
# Entrenando XGBoost...
# XGBoost - RMSE: 7.628802513003315
# Entrenando SVR...
# SVR - RMSE: 0.3705296395655994
# 🏆 Mejor modelo: SVR con RMSE: 0.3705

# %% [markdown]
# FLUIDRA

# %%
# --- PARÁMETROS ---

empresa = "FLUIDRA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.4466624428171909
# Entrenando Decision Tree...
# Decision Tree - RMSE: 2.1361243340477176
# Entrenando Random Forest...
# Random Forest - RMSE: 1.8170655482348552
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.8445954647512457
# Entrenando XGBoost...
# XGBoost - RMSE: 1.0443256709149937
# Entrenando SVR...
# SVR - RMSE: 0.4422016891471929
# 🏆 Mejor modelo: SVR con RMSE: 0.4422

# %% [markdown]
# GRIFOLS

# %%
# --- PARÁMETROS ---

empresa = "GRIFOLS"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.41237890665269633
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.847038845705293
# Entrenando Random Forest...
# Random Forest - RMSE: 0.6403222221229083
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.9639433834911393
# Entrenando XGBoost...
# XGBoost - RMSE: 0.7914081516456005
# Entrenando SVR...
# SVR - RMSE: 0.4260694875608932
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.4124

# %% [markdown]
# IAG

# %%
# --- PARÁMETROS ---

empresa = "IAG"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.04922846832031789
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.07057817802093899
# Entrenando Random Forest...
# Random Forest - RMSE: 0.050196639245678513
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.05592633014767586
# Entrenando XGBoost...
# XGBoost - RMSE: 0.05968564253984533
# Entrenando SVR...
# SVR - RMSE: 0.045299639649088105
# 🏆 Mejor modelo: SVR con RMSE: 0.0453

# %% [markdown]
# IBERDROLA

# %%
# --- PARÁMETROS ---

empresa = "IBERDROLA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.11525301685023184
# Entrenando Decision Tree...
# Decision Tree - RMSE: 2.012973559060273
# Entrenando Random Forest...
# Random Forest - RMSE: 1.788818956737539
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.8099764002026701
# Entrenando XGBoost...
# XGBoost - RMSE: 2.0202868169348025
# Entrenando SVR...
# SVR - RMSE: 0.12192595683480875
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.1153

# %% [markdown]
# INDITEX

# %%
# --- PARÁMETROS ---

empresa = "INDITEX"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.5279298214356463
# Entrenando Decision Tree...
# Decision Tree - RMSE: 11.30060018328172
# Entrenando Random Forest...
# Random Forest - RMSE: 11.594166955517066
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 11.646531990937078
# Entrenando XGBoost...
# XGBoost - RMSE: 11.491853176288023
# Entrenando SVR...
# SVR - RMSE: 0.5296293224787847
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.5279

# %% [markdown]
# INDRA

# %%
# --- PARÁMETROS ---

empresa = "INDRA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.27857447249279116
# Entrenando Decision Tree...
# Decision Tree - RMSE: 3.6012955360183687
# Entrenando Random Forest...
# Random Forest - RMSE: 3.6002354603804987
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 3.575272176145944
# Entrenando XGBoost...
# XGBoost - RMSE: 3.720511796278483
# Entrenando SVR...
# SVR - RMSE: 0.2832990762597319
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.2786

# %% [markdown]
# INM

# %%
# --- PARÁMETROS ---

empresa = "INM. COLONIAL"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.1012568322658135
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.16844461227000854
# Entrenando Random Forest...
# Random Forest - RMSE: 0.1095646650136651
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.1758922023126281
# Entrenando XGBoost...
# XGBoost - RMSE: 0.11517903929834054
# Entrenando SVR...
# SVR - RMSE: 0.10147462398496851
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.1013

# %%
LABORATORIOS FARMA

# %%
# --- PARÁMETROS ---

empresa = "LABORATORIOS FARMA (ROVI)"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 1.3058321131859596
# Entrenando Decision Tree...
# Decision Tree - RMSE: 10.551257231624112
# Entrenando Random Forest...
# Random Forest - RMSE: 8.948735075660723
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 8.96113503191046
# Entrenando XGBoost...
# XGBoost - RMSE: 7.334384647451025
# Entrenando SVR...
# SVR - RMSE: 1.4573615063709557
# 🏆 Mejor modelo: Linear Regression con RMSE: 1.3058

# %% [markdown]
# LOGISTA

# %%
# --- PARÁMETROS ---

empresa = "LOGISTA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 1.4439327147243337
# Entrenando Decision Tree...
# Decision Tree - RMSE: 10.402225019757573
# Entrenando Random Forest...
# Random Forest - RMSE: 8.857543688970603
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 8.975887618804007
# Entrenando XGBoost...
# XGBoost - RMSE: 8.462390034412836
# Entrenando SVR...
# SVR - RMSE: 1.4111084708295505
# 🏆 Mejor modelo: SVR con RMSE: 1.4111

# %% [markdown]
# MAPFRE

# %%
# --- PARÁMETROS ---

empresa = "MAPFRE"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.02330319652987165
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.3054541694493591
# Entrenando Random Forest...
# Random Forest - RMSE: 0.3061266547870718
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.31455689228160305
# Entrenando XGBoost...
# XGBoost - RMSE: 0.3178513476895887
# Entrenando SVR...
# SVR - RMSE: 0.03497915830625155
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.0233

# %% [markdown]
# MERLIN

# %%
# --- PARÁMETROS ---

empresa = "MERLIN PROPERTIES"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.22207380352104283
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.7024716926659277
# Entrenando Random Forest...
# Random Forest - RMSE: 0.6916024836894817
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.9543259848491314
# Entrenando XGBoost...
# XGBoost - RMSE: 0.7884462649638406
# Entrenando SVR...
# SVR - RMSE: 0.20305334909978176
# 🏆 Mejor modelo: SVR con RMSE: 0.2031

# %% [markdown]
# NATURGY

# %%
# --- PARÁMETROS ---

empresa = "NATURGY"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.32304047238882133
# Entrenando Decision Tree...
# Decision Tree - RMSE: 2.5097551849835664
# Entrenando Random Forest...
# Random Forest - RMSE: 1.7104585318090102
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 2.0923697016542597
# Entrenando XGBoost...
# XGBoost - RMSE: 1.562494937325416
# Entrenando SVR...
# SVR - RMSE: 0.32445324441416085
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.3230

# %% [markdown]
# PUIG

# %%
# --- PARÁMETROS ---

empresa = "PUIG"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte='2025-01-01'
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 4.871326408740954
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.8073397722094353
# Entrenando Random Forest...
# Random Forest - RMSE: 0.8892688191249637
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.7420706405934404
# Entrenando XGBoost...
# XGBoost - RMSE: 0.7154765455388533
# Entrenando SVR...
# SVR - RMSE: 4.121771385191289
# 🏆 Mejor modelo: XGBoost con RMSE: 0.7155

# %% [markdown]
# REE

# %%
# --- PARÁMETROS ---

empresa = "REE"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.17367114929463773
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.7432972187961873
# Entrenando Random Forest...
# Random Forest - RMSE: 0.7591790930373775
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.8502662947919758
# Entrenando XGBoost...
# XGBoost - RMSE: 0.84871703853951
# Entrenando SVR...
# SVR - RMSE: 0.17499695294348852
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.1737

# %% [markdown]
# REPSOL

# %%
# --- PARÁMETROS ---

empresa = "REPSOL"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.20726171465816914
# Entrenando Decision Tree...
# Decision Tree - RMSE: 1.4731341513065934
# Entrenando Random Forest...
# Random Forest - RMSE: 1.464280371130135
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.525872978584452
# Entrenando XGBoost...
# XGBoost - RMSE: 1.4892788806782657
# Entrenando SVR...
# SVR - RMSE: 0.2043909402079762
# 🏆 Mejor modelo: SVR con RMSE: 0.2044

# %% [markdown]
# SABADELL

# %%
# --- PARÁMETROS ---

empresa = "SABADELL"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.0283805286656152
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.2860048116300052
# Entrenando Random Forest...
# Random Forest - RMSE: 0.2891342848126414
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.2860474401754227
# Entrenando XGBoost...
# XGBoost - RMSE: 0.2879657150567439
# Entrenando SVR...
# SVR - RMSE: 0.08295476801363968
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.0284

# %% [markdown]
# SACYR

# %%
# --- PARÁMETROS ---

empresa = "SACYR"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.043749678529147185
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.06750228096382399
# Entrenando Random Forest...
# Random Forest - RMSE: 0.048171162646565055
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.049903089761014846
# Entrenando XGBoost...
# XGBoost - RMSE: 0.051469938405621314
# Entrenando SVR...
# SVR - RMSE: 0.07404013670586632
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.0437

# %% [markdown]
# SANTANDER

# %%
# --- PARÁMETROS ---

empresa = "SANTANDER"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.06920702532724955
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.3179800502654615
# Entrenando Random Forest...
# Random Forest - RMSE: 0.3004934501306587
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.31697706841608014
# Entrenando XGBoost...
# XGBoost - RMSE: 0.3285856434999805
# Entrenando SVR...
# SVR - RMSE: 0.07012104202952336
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.0692

# %% [markdown]
# SOLARIA

# %%
# --- PARÁMETROS ---

empresa = "SOLARIA ENERGIA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.4041007768346967
# Entrenando Decision Tree...
# Decision Tree - RMSE: 1.6284073203252465
# Entrenando Random Forest...
# Random Forest - RMSE: 0.9649718091216402
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 1.5728652110235075
# Entrenando XGBoost...
# XGBoost - RMSE: 1.1904333434015784
# Entrenando SVR...
# SVR - RMSE: 0.413822536482213
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.4041

# %% [markdown]
# TELEFONICA

# %%
# --- PARÁMETROS ---

empresa = "TELEFONICA"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2022-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 0.041789283392834595
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.2503267513129026
# Entrenando Random Forest...
# Random Forest - RMSE: 0.17999301161297582
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.18275738371965292
# Entrenando XGBoost...
# XGBoost - RMSE: 0.08555867995373267
# Entrenando SVR...
# SVR - RMSE: 0.04368032392185247
# 🏆 Mejor modelo: Linear Regression con RMSE: 0.0418

# %% [markdown]
# UNICAJA

# %%
# --- PARÁMETROS ---

empresa = "UNICAJA BANCO"

# --- 1. Cargar y preparar los datos ---
df = cargar_datos(ruta_datos, empresa)
df = crear_variables_lag_y_temporales(df)

# --- 2. Dividir en entrenamiento y prueba ---
fecha_corte="2023-04-01"
X_train, y_train, X_test, y_test = dividir_train_test(df, fecha_test=fecha_corte)
X_train, X_test = escalar_datos(X_train, X_test)


# --- 3. Entrenar y evaluar modelos ---
models, param_grids = definir_modelos()
best_model_name, best_model, best_rmse = entrenar_y_evaluar_modelos(
    X_train, y_train, X_test, y_test, models, param_grids
)

print(f"🏆 Mejor modelo: {best_model_name} con RMSE: {best_rmse:.4f}")

# --- 4. Predicción y visualización ---
y_pred = best_model.predict(X_test)
graficar_predicciones(y_test, y_pred, titulo=f"{empresa} - {best_model_name}")
# Out:
# Entrenando Linear Regression...
# Linear Regression - RMSE: 11.029064012807087
# Entrenando Decision Tree...
# Decision Tree - RMSE: 0.21628548520866242
# Entrenando Random Forest...
# Random Forest - RMSE: 0.24752446222944338
# Entrenando Gradient Boosting...
# Gradient Boosting - RMSE: 0.22802218376708142
# Entrenando XGBoost...
# XGBoost - RMSE: 0.2627053065123613
# Entrenando SVR...
# SVR - RMSE: 0.30949785991322876
# 🏆 Mejor modelo: Decision Tree con RMSE: 0.2163
