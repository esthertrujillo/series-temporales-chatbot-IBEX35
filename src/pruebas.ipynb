# %%
import os
import sys
import pickle
import pandas as pd
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import numpy as np

# %%
import importlib
import predicciones_modelo_global
importlib.reload(predicciones_modelo_global)

from predicciones_modelo_global import predicciones


ruta_csv = "/Users/luciamenendezfernandez/Desktop/TFM lucia/data/IBEX35_cotizaciones_20_Limpio.csv"
modelos_dir = "/Users/luciamenendezfernandez/Desktop/TFM lucia/modelos"

y_pred, y_real, rmse, ultima_pred = predicciones("BBVA", 7, ruta_csv, modelos_dir)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator SVR from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 📈 RMSE para BBVA con lag 7: 80.2937
# 🔮 Última predicción: 190.60 €

# %%
from predicciones_por_empresa import predicciones

ruta_csv = "/Users/luciamenendezfernandez/Desktop/TFM lucia/data/IBEX35_cotizaciones_20_Limpio.csv"
modelos_dir = "/Users/luciamenendezfernandez/Desktop/TFM lucia/modelos_por_empresa"

# Llamada para una empresa concreta y horizonte
y_pred, y_real, rmse, ultima = predicciones("BBVA", 7, ruta_csv, modelos_dir)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator SVR from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 📈 RMSE para BBVA con lag 7: 0.5450
# 🔮 Última predicción: 12.28 €

# %%
from predicciones_por_empresa import predicciones

ruta_csv = "/Users/luciamenendezfernandez/Desktop/TFM lucia/data/IBEX35_cotizaciones_20_Limpio.csv"
modelos_dir = "/Users/luciamenendezfernandez/Desktop/TFM lucia/modelos_por_empresa"

# Llamada para una empresa concreta y horizonte
y_pred, y_real, rmse, ultima = predicciones("BBVA", 1, ruta_csv, modelos_dir)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 📈 RMSE para BBVA con lag 1: 0.1502
# 🔮 Última predicción: 12.45 €

# %%
from predicciones_por_empresa import predicciones

ruta_csv = "/Users/luciamenendezfernandez/Desktop/TFM lucia/data/IBEX35_cotizaciones_20_Limpio.csv"
modelos_dir = "/Users/luciamenendezfernandez/Desktop/TFM lucia/modelos_por_empresa"

# Llamada para una empresa concreta y horizonte
y_pred, y_real, rmse, ultima = predicciones("BBVA", 15, ruta_csv, modelos_dir)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator SVR from version 1.5.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# 📈 RMSE para BBVA con lag 15: 0.8451
# 🔮 Última predicción: 11.41 €
